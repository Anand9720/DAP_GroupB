# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Stored IMDB data in d1

# %%
d1=pd.read_csv("Imdb_dataset_+1.csv")

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Titles             6000 non-null   object
#  1   Year               6000 non-null   int64
#  2   Genre              6000 non-null   object
#  3   Revenue(Millions)  5027 non-null   float64
#  4   Votes              6000 non-null   int64
#  5   Director           6000 non-null   object
#  6   Star               6000 non-null   object
#  7   Certificate        5943 non-null   object
#  8   Runtime            5999 non-null   float64
#  9   Rating             6000 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 468.9+ KB

# %% [markdown]
# ### Stored Netflix data in d2

# %%
d2=pd.read_csv("Netflix cleaner data.csv")

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           8790 non-null   object
#  1   type              8790 non-null   object
#  2   title             8790 non-null   object
#  3   cast              8790 non-null   object
#  4   country           8790 non-null   object
#  5   release_year      8790 non-null   int64
#  6   rating            8790 non-null   object
#  7   duration          8790 non-null   object
#  8   listed_in         8790 non-null   object
#  9   description       8790 non-null   object
#  10  month_added       8790 non-null   int64
#  11  month_name_added  8790 non-null   object
#  12  year_added        8790 non-null   int64
# dtypes: int64(3), object(10)
# memory usage: 892.9+ KB

# %%
d1.rename(columns={'Titles': 'title'}, inplace=True)

# %%
key_column = 'title'
d1[key_column] = d1[key_column].astype(str) #coverted column into strings
d2[key_column] = d2[key_column].astype(str)

# %%
d1 = d1.sort_values(key_column) # sort the movies name
d2 = d2.sort_values(key_column)

# %% [markdown]
# ### Merged IMDB and Netflix Data

# %%
merged_data = pd.merge(d1, d2, on=key_column)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1221 entries, 0 to 1220
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1221 non-null   object
#  1   Year               1221 non-null   int64
#  2   Genre              1221 non-null   object
#  3   Revenue(Millions)  989 non-null    float64
#  4   Votes              1221 non-null   int64
#  5   Director           1221 non-null   object
#  6   Star               1221 non-null   object
#  7   Certificate        1216 non-null   object
#  8   Runtime            1221 non-null   float64
#  9   Rating             1221 non-null   float64
#  10  show_id            1221 non-null   object
#  11  type               1221 non-null   object
#  12  cast               1221 non-null   object
#  13  country            1221 non-null   object
#  14  release_year       1221 non-null   int64
#  15  rating             1221 non-null   object
#  16  duration           1221 non-null   object
#  17  listed_in          1221 non-null   object
#  18  description        1221 non-null   object
#  19  month_added        1221 non-null   int64
#  20  month_name_added   1221 non-null   object
#  21  year_added         1221 non-null   int64
# dtypes: float64(3), int64(5), object(14)
# memory usage: 219.4+ KB

# %% [markdown]
# ### import Amazon data

# %%
import pandas as pd

# Load the JSON data into a pandas dataframe
with open('amazon_prime_titles_output.json', 'r') as f:
    data = pd.read_json(f)

# Convert the dataframe to CSV format
data.to_csv('data11.csv', index=False)

# %%
d3=pd.read_csv("data11.csv")

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
key_column = 'title'
d1[key_column] = d1[key_column].astype(str)
d3[key_column] = d3[key_column].astype(str)

# %% [markdown]
# ### merged IMDB and Amazon data

# %%
merged_data2 = pd.merge(d1, d3, on=key_column)

# %%
merged_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 532 entries, 0 to 531
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              532 non-null    object
#  1   Year               532 non-null    int64
#  2   Genre              532 non-null    object
#  3   Revenue(Millions)  437 non-null    float64
#  4   Votes              532 non-null    int64
#  5   Director           532 non-null    object
#  6   Star               532 non-null    object
#  7   Certificate        528 non-null    object
#  8   Runtime            532 non-null    float64
#  9   Rating             532 non-null    float64
#  10  show_id            532 non-null    object
#  11  type               532 non-null    object
#  12  director           482 non-null    object
#  13  cast               523 non-null    object
#  14  country            97 non-null     object
#  15  date_added         2 non-null      object
#  16  release_year       532 non-null    int64
#  17  rating             528 non-null    object
#  18  duration           532 non-null    object
#  19  listed_in          532 non-null    object
#  20  description        532 non-null    object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 91.4+ KB

# %%
merged_data
# Out:
#                          title  Year                                  Genre  \
# 0                       #Alive  2020      Action, Drama, Horror
# 1                      13 Sins  2014           Horror, Thriller
# 2                    16 Blocks  2006    Action, Drama, Thriller
# 3                     17 Again  2009     Comedy, Drama, Fantasy
# 4                         1922  2017       Crime, Drama, Horror
# ...                        ...   ...                                    ...
# 1216                      Zero  2018     Comedy, Drama, Romance
# 1217  Zindagi Na Milegi Dobara  2011     Comedy, Drama, Musical
# 1218                    Zodiac  2007      Crime, Drama, Mystery
# 1219                Zombieland  2009     Action, Comedy, Horror
# 1220                  Æon Flux  2005  Action, Adventure, Sci-Fi
#
#       Revenue(Millions)   Votes         Director  \
# 0                   NaN   42998           Il Cho
# 1                  0.01   37612     Daniel Stamm
# 2                 36.90  132520   Richard Donner
# 3                 64.17  207145      Burr Steers
# 4                   NaN   66762     Zak Hilditch
# ...                 ...     ...              ...
# 1216                NaN   28871    Aanand L. Rai
# 1217               3.11   81000      Zoya Akhtar
# 1218              33.08  558714    David Fincher
# 1219              75.59  592866  Ruben Fleischer
# 1220              25.86  130499     Karyn Kusama
#
#                                                    Star Certificate  Runtime  \
# 0     Yoo Ah-in, Park Shin-Hye, Jeon Bae-soo, Hyun-W...       TV-MA     98.0
# 1     Mark Webber, Devon Graye, Tom Bower, Rutina We...           R     93.0
# 2     Bruce Willis, Yasiin Bey, David Morse, Jenna S...       PG-13    102.0
# 3     Zac Efron, Matthew Perry, Leslie Mann, Thomas ...       PG-13    102.0
# 4     Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...       TV-MA    102.0
# ...                                                 ...         ...      ...
# 1216  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...   Not Rated    164.0
# 1217  Hrithik Roshan, Farhan Akhtar, Abhay Deol, Kat...   Not Rated    155.0
# 1218  Jake Gyllenhaal, Robert Downey Jr., Mark Ruffa...           R    157.0
# 1219  Jesse Eisenberg, Emma Stone, Woody Harrelson, ...           R     88.0
# 1220  Charlize Theron, Frances McDormand, Sophie Oko...       PG-13     93.0
#
#       Rating  ...                                               cast  \
# 0        6.3  ...                           Yoo Ah-in, Park Shin-hye
# 1        6.3  ...  Mark Webber, Rutina Wesley, Devon Graye, Tom B...
# 2        6.6  ...  Bruce Willis, Mos Def, David Morse, Jenna Ster...
# 3        6.4  ...  Zac Efron, Leslie Mann, Matthew Perry, Thomas ...
# 4        6.2  ...  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...      ...  ...                                                ...
# 1216     5.2  ...  Giuseppe Dave Seke, Haroun Fall, Beatrice Gran...
# 1217     8.2  ...  Hrithik Roshan, Abhay Deol, Farhan Akhtar, Kat...
# 1218     7.7  ...  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 1219     7.6  ...  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 1220     5.4  ...  Charlize Theron, Marton Csokas, Jonny Lee Mill...
#
#                      country release_year rating  duration  \
# 0                South Korea         2020  TV-MA    99 min
# 1              United States         2014      R    93 min
# 2     United States, Germany         2006  PG-13   102 min
# 3              United States         2009  PG-13   102 min
# 4              United States         2017  TV-MA   103 min
# ...                      ...          ...    ...       ...
# 1216                   Italy         2021  TV-MA  1 Season
# 1217                   India         2011  TV-14   154 min
# 1218           United States         2007      R   158 min
# 1219           United States         2009      R    88 min
# 1220           United States         2005  PG-13    93 min
#
#                                            listed_in  \
# 0     Horror Movies, International Movies, Thrillers
# 1                           Horror Movies, Thrillers
# 2                                 Action & Adventure
# 3                                           Comedies
# 4                                  Dramas, Thrillers
# ...                                              ...
# 1216  International TV Shows, TV Comedies, TV Dramas
# 1217          Comedies, Dramas, International Movies
# 1218                  Cult Movies, Dramas, Thrillers
# 1219                         Comedies, Horror Movies
# 1220            Action & Adventure, Sci-Fi & Fantasy
#
#                                             description month_added  \
# 0     As a grisly virus rampages a city, a lone man ...           9
# 1     A man agrees to appear on a game show with a $...           1
# 2     Tasked with escorting a prosecution witness to...          11
# 3     Nearing a midlife crisis, thirty-something Mik...           1
# 4     A farmer pens a confession admitting to his wi...          10
# ...                                                 ...         ...
# 1216  A shy teen with the power to turn invisible mu...           4
# 1217  Three friends on an adventurous road trip/bach...          12
# 1218  A political cartoonist, a crime reporter and a...          11
# 1219  Looking to survive in a world taken over by zo...          11
# 1220  Aiming to hasten an uprising, the leader of an...           2
#
#      month_name_added  year_added
# 0           September        2020
# 1             January        2019
# 2            November        2019
# 3             January        2021
# 4             October        2017
# ...               ...         ...
# 1216            April        2021
# 1217         December        2019
# 1218         November        2019
# 1219         November        2019
# 1220         February        2018
#
# [1221 rows x 22 columns]

# %% [markdown]
# ### what is top rated movie in Netflix

# %%
top_rating_by_netflix= merged_data.nlargest(10,'Rating')[['title','Rating','Director']].set_index('title')

# %%
top_rating_by_netflix
# Out:
#                                                Rating  \
# title
# Schindler's List                                  9.0
# The Lord of the Rings: The Return of the King     9.0
# Pulp Fiction                                      8.9
# Inception                                         8.8
# The Lord of the Rings: The Two Towers             8.8
# The Matrix                                        8.7
# City of God                                       8.6
# American History X                                8.5
# Once Upon a Time in the West                      8.5
# Psycho                                            8.5
#
#                                                                       Director
# title
# Schindler's List                                              Steven Spielberg
# The Lord of the Rings: The Return of the King                    Peter Jackson
# Pulp Fiction                                                 Quentin Tarantino
# Inception                                                    Christopher Nolan
# The Lord of the Rings: The Two Towers                            Peter Jackson
# The Matrix                                     Lana Wachowski, Lilly Wachowski
# City of God                                     Fernando Meirelles, Kátia Lund
# American History X                                                   Tony Kaye
# Once Upon a Time in the West                                      Sergio Leone
# Psycho                                                        Alfred Hitchcock

# %% [markdown]
# ### what is highest revenue generated movie in Netflix

# %%
Highest_revenue_by_netflix= merged_data.nlargest(10,'Revenue(Millions)')[['title','Revenue(Millions)','Director']].set_index('title')

# %%
Highest_revenue_by_netflix
# Out:
#                                                     Revenue(Millions)  \
# title
# Black Panther                                                  700.06
# Avengers: Infinity War                                         678.82
# The Lord of the Rings: The Return of the King                  377.85
# The Jungle Book                                                364.00
# The Lord of the Rings: The Two Towers                          342.55
# Spider-Man 3                                                   336.53
# Joker                                                          335.45
# Indiana Jones and the Kingdom of the Crystal Skull             317.10
# Thor: Ragnarok                                                 315.06
# The Twilight Saga: Eclipse                                     300.53
#
#                                                                     Director
# title
# Black Panther                                                   Ryan Coogler
# Avengers: Infinity War                              Anthony Russo, Joe Russo
# The Lord of the Rings: The Return of the King                  Peter Jackson
# The Jungle Book                                                  Jon Favreau
# The Lord of the Rings: The Two Towers                          Peter Jackson
# Spider-Man 3                                                       Sam Raimi
# Joker                                                          Todd Phillips
# Indiana Jones and the Kingdom of the Crystal Skull          Steven Spielberg
# Thor: Ragnarok                                                 Taika Waititi
# The Twilight Saga: Eclipse                                       David Slade

# %% [markdown]
# # In which year revenue was most generated in netflix

# %%
def plot_top_yearly_revenues_by_netflix(df, n=10):
    # Group by Year and calculate mean Revenue, and sort in descending order
    yearly_revenues = merged_data.groupby('Year')['Revenue(Millions)'].mean().sort_values(ascending=False)[:n]

    # Create a horizontal bar plot
    plt.figure(figsize=(10,6))
    colors = sns.color_palette("rocket_r", len(yearly_revenues))
    sns.barplot(x=yearly_revenues.index, y=yearly_revenues.values, palette=colors)

    # Set axis labels and title
    plt.xlabel('Year')
    plt.ylabel('Revenue (Millions)')
    plt.title(f'Top {n} Years with Highest Average Revenue by netflix')
    plt.xticks(rotation=90)
    # Show the plot
    
    plt.show()
plot_top_yearly_revenues_by_netflix(merged_data, 20)

# %% [markdown]
# ### what is top rated movie in Netflix

# %%
top_rating_by_amazon= merged_data2.nlargest(10,'Rating')[['title','Rating','Director']].set_index('title')

# %%
top_rating_by_amazon
# Out:
#                   Rating           Director
# title
# Asuran               8.4        Vetrimaaran
# Drishyam 2           8.4      Jeethu Joseph
# Joker                8.4      Todd Phillips
# M                    8.3         Fritz Lang
# Shershaah            8.3      Vishnuvardhan
# The Hunt             8.3  Thomas Vinterberg
# Die Hard             8.2     John McTiernan
# Drishyam 2           8.2    Abhishek Pathak
# The Elephant Man     8.2        David Lynch
# The Father           8.2     Florian Zeller

# %% [markdown]
# ### what is highest revenue generated movie in Netflix

# %%
Highest_revenue_by_amazon= merged_data2.nlargest(10,'Revenue(Millions)')[['title','Revenue(Millions)','Director']].set_index('title')

# %%
Highest_revenue_by_amazon
# Out:
#                       Revenue(Millions)                        Director
# title
# Beauty and the Beast             504.01                     Bill Condon
# Inside Out                       356.46  Pete Docter, Ronnie Del Carmen
# Joker                            335.45                   Todd Phillips
# Alice in Wonderland              334.19                      Tim Burton
# The Exorcist                     232.91                William Friedkin
# Beauty and the Beast             218.97       Gary Trousdale, Kirk Wise
# Armageddon                       201.57                     Michael Bay
# Cinderella                       201.15                 Kenneth Branagh
# Twilight                         192.77             Catherine Hardwicke
# Black Widow                      183.65                  Cate Shortland

# %% [markdown]
# ### In which year revenue was most generated in netflix¶

# %%
def plot_top_yearly_revenues_by_amazon(df, n=10):
    # Group by Year and calculate mean Revenue, and sort in descending order
    yearly_revenues = merged_data2.groupby('Year')['Revenue(Millions)'].mean().sort_values(ascending=False)[:n]

    # Create a horizontal bar plot
    plt.figure(figsize=(10,6))
    colors = sns.color_palette("rocket_r", len(yearly_revenues))
    sns.barplot(x=yearly_revenues.index, y=yearly_revenues.values, palette=colors)

    # Set axis labels and title
    plt.xlabel('Year')
    plt.ylabel('Revenue (Millions)')
    plt.title(f'Top {n} Years with Highest Average Revenue by amazon')
    plt.xticks(rotation=90)
    # Show the plot
    
    plt.show()
plot_top_yearly_revenues_by_amazon(merged_data2, 20)
